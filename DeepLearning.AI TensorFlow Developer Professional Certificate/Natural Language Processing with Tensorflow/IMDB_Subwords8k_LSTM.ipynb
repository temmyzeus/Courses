# %% [markdown]
# <a href="https://colab.research.google.com/github/temmyzeus/Tensorflow-Courses/blob/master/DeepLearning.AI%20TensorFlow%20Developer%20Professional%20Certificate/Natural%20Language%20Processing%20with%20Tensorflow/IMDB_Subwords8k_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import Union, Dict
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, LSTM, Bidirectional

# %%
imdb, info = tfds.load(
    'imdb_reviews/subwords8k',
    with_info=True,
    as_supervised=True
)
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)
# Downloading and preparing dataset imdb_reviews/subwords8k/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteQJJKFJ/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteQJJKFJ/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteQJJKFJ/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0. Subsequent calls will reuse this data.

# %%
train = imdb['train']
test = imdb['test']
# Get Subword Text Encoder
tokenizer = info.features['text'].encoder

# %%
# convert sample_tokens to text
sample_text = 'I\'m going to be a very good ML Engineer'
sample_tokens = tokenizer.encode(sample_text)

print(tokenizer.encode(sample_text), end='\n\n')
print(tokenizer.decode(sample_tokens))
# Out:
# [8002, 7968, 111, 215, 7, 35, 4, 67, 74, 8006, 3780, 1844, 1004, 1225, 8043]
#
# I'm going to be a very good ML Engineer

# %%
# Getting an Idea of teh distribution of token lengths
train_lens = np.array([len(_[0]) for _ in train])
print('Min Len :', np.min(train_lens))
print('Max Len: ', np.max(train_lens))
# Getting a good sense of the middle point, median seems better here
print('Median Len', np.median(train_lens))
plt.hist(train_lens, bins=30)
plt.show()
# Out:
# Min Len : 11
# Max Len:  3944
# Median Len 253.0

# %%
vocab_size = tokenizer.vocab_size
output_dim = 20
input_length = 500
BATCH_SIZE = 64
BUFFER_SIZE = 10000
EPOCHS = 20

# %%
train_ds = train.shuffle(buffer_size=BUFFER_SIZE)
train_padded = train_ds.padded_batch(
    batch_size=BATCH_SIZE,
    padded_shapes=tf.compat.v1.data.get_output_shapes(train)
)

test_padded = test.padded_batch(
    batch_size=BATCH_SIZE,
    padded_shapes=tf.compat.v1.data.get_output_shapes(test)
)

# %%
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=output_dim, input_length=input_length) ,
    LSTM(units=output_dim),
    Dense(10, activation='relu'),
    Dense(1, activation='sigmoid')
], name='IMDB_CLassifier')

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop',
    metrics=['accuracy']
)
history = model.fit(
    train_padded,
    validation_data=test_padded,
    epochs = EPOCHS
)
# Out:
# Epoch 1/20
# 391/391 [==============================] - 88s 205ms/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6931 - val_accuracy: 0.5021
# Epoch 2/20
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6931 - accuracy: 0.5013 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 3/20
# 391/391 [==============================] - 77s 195ms/step - loss: 0.6926 - accuracy: 0.4988 - val_loss: 0.6968 - val_accuracy: 0.5000
# Epoch 4/20
# 391/391 [==============================] - 75s 189ms/step - loss: 0.6916 - accuracy: 0.5051 - val_loss: 0.6921 - val_accuracy: 0.5038
# Epoch 5/20
# 391/391 [==============================] - 80s 202ms/step - loss: 0.6978 - accuracy: 0.5018 - val_loss: 0.6907 - val_accuracy: 0.5060
# Epoch 6/20
# 391/391 [==============================] - 76s 192ms/step - loss: 0.6885 - accuracy: 0.5021 - val_loss: 0.6919 - val_accuracy: 0.5040
# Epoch 7/20
# 391/391 [==============================] - 73s 186ms/step - loss: 0.6885 - accuracy: 0.5078 - val_loss: 0.6923 - val_accuracy: 0.5046
# Epoch 8/20
# 391/391 [==============================] - 78s 197ms/step - loss: 0.6974 - accuracy: 0.5039 - val_loss: 0.6912 - val_accuracy: 0.5030
# Epoch 9/20
# 391/391 [==============================] - 75s 189ms/step - loss: 0.7106 - accuracy: 0.5183 - val_loss: 0.7099 - val_accuracy: 0.6398
# Epoch 10/20
# 391/391 [==============================] - 72s 181ms/step - loss: 0.6334 - accuracy: 0.6753 - val_loss: 0.6215 - val_accuracy: 0.6804
# Epoch 11/20
# 391/391 [==============================] - 73s 185ms/step - loss: 0.6081 - accuracy: 0.6985 - val_loss: 0.6041 - val_accuracy: 0.7076
# Epoch 12/20
# 391/391 [==============================] - 70s 178ms/step - loss: 0.6505 - accuracy: 0.6028 - val_loss: 0.6016 - val_accuracy: 0.7096
# Epoch 13/20
# 391/391 [==============================] - 71s 179ms/step - loss: 0.6008 - accuracy: 0.7026 - val_loss: 0.6298 - val_accuracy: 0.6540
# Epoch 14/20
# 391/391 [==============================] - 71s 179ms/step - loss: 0.6061 - accuracy: 0.6998 - val_loss: 0.6150 - val_accuracy: 0.7043
# Epoch 15/20
# 391/391 [==============================] - 70s 177ms/step - loss: 0.6008 - accuracy: 0.7064 - val_loss: 0.6002 - val_accuracy: 0.7138
# Epoch 16/20
# 391/391 [==============================] - 75s 189ms/step - loss: 0.5863 - accuracy: 0.7224 - val_loss: 0.5939 - val_accuracy: 0.7226
# Epoch 17/20
# 391/391 [==============================] - 71s 179ms/step - loss: 0.5918 - accuracy: 0.7168 - val_loss: 0.6042 - val_accuracy: 0.7121
# Epoch 18/20
# 391/391 [==============================] - 76s 191ms/step - loss: 0.5933 - accuracy: 0.7157 - val_loss: 0.6198 - val_accuracy: 0.7072
# Epoch 19/20
# 391/391 [==============================] - 70s 178ms/step - loss: 0.5858 - accuracy: 0.7233 - val_loss: 0.6075 - val_accuracy: 0.7080
# Epoch 20/20
# 391/391 [==============================] - 70s 176ms/step - loss: 0.6061 - accuracy: 0.6907 - val_loss: 0.6144 - val_accuracy: 0.7026

# %%
def plot_loss_acc(history: Union[tf.keras.callbacks.History, Dict]):
    if isinstance(history, tf.keras.callbacks.History):
        history = history.history
    elif isinstance(history, dict):
        pass
    else:
        raise TypeError

    epochs_axis = list(map(int, list(range(1, len(history['loss'])+1))))
    plt.figure(figsize=(15, 5))
    ax1 = plt.subplot(1, 2, 1)
    ax2 = plt.subplot(1, 2, 2)
    ax1.plot(epochs_axis, history['loss'], color='orange', label='Train Loss')
    ax1.plot(epochs_axis, history['val_loss'], color='b', label='Val Loss')
    ax1.set_xticks(ticks=epochs_axis)
    ax1.legend()

    ax2.plot(epochs_axis, history['accuracy'], color='orange', label='Train Accuracy')
    ax2.plot(epochs_axis, history['val_accuracy'], color='b', label='Val Accuracy')
    ax2.set_xticks(ticks=epochs_axis)
    ax2.legend()
    plt.show()

plot_loss_acc(history)
